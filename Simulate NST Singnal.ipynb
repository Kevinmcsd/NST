# %%
import numpy as np

# %%
base_line=int(np.random.normal(loc=135,scale=20))
# Out:
# 153
# 156
# 112
# 105
# 112
# 85
# 146
# 118
# 118
# 125
# 102
# 156
# 129
# 117
# 137
# 140
# 125
# 124
# 142
# 107
# 118
# 135
# 127
# 133
# 137
# 139
# 150
# 181
# 123
# 185
# 162
# 143
# 169
# 128
# 137
# 112
# 122
# 162
# 145
# 153
